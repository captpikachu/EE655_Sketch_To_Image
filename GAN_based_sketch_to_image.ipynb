# %%
import tensorflow as tf
import numpy as np
import os
import cv2
from glob import glob
from tensorflow.keras import layers # to use custom layers , we used custom activation function, also skip connections to preseerve details
import random # to shuffle dataset as images are taken from an online  dataset there may be patterns so we shuffle
#dataset so that our model can be trained better

# %%
# Parameters
IMAGE_SIZE = 128
BATCH_SIZE = 4
AUTOTUNE = tf.data.AUTOTUNE
EPOCHS = 10

imgpth = "F:\\Python\\EE655\\dataset\\trainA"
image_paths = glob(os.path.join(imgpth, "*.jpg")) + glob(os.path.join(imgpth, "*.png")) + glob(os.path.join(imgpth, "*.jpeg"))
random.shuffle(image_paths)

# %%
# Sketch generation (using Canny edge)
def create_sketch(image_np):
    if image_np.shape[-1] == 3:
        gray = cv2.cvtColor(image_np, cv2.COLOR_RGB2GRAY) 
    else:
        gray = image_np[..., 0]

    if gray.dtype != np.uint8:
        gray = (gray * 255).astype(np.uint8) if gray.max() <= 1.0 else gray.astype(np.uint8)

    edges = cv2.Canny(gray, threshold1=100, threshold2=200)
    sketch = edges.astype(np.float32) / 255.0
    sketch = np.expand_dims(sketch, axis=-1)
    return sketch
# in input also we have to use canny sketches even if user givves hand drawn sketches aswe are training over
#edge detected sketches

# %%
# Preprocess function
def preprocess(path):
    image = tf.io.read_file(path)
    image = tf.image.decode_image(image, channels=3)
    image.set_shape([None, None, 3])
    image = tf.image.resize(image, [IMAGE_SIZE, IMAGE_SIZE])
    image_np = image.numpy()
    sketch = create_sketch(image_np)

    sketch = (sketch * 2.0) - 1.0 # normalise pixel values to use activation function, we use tanh activation for GAN 
    image = (image_np / 127.5) - 1.0
    return sketch.astype(np.float32), image.astype(np.float32) 

def tf_preprocess(path):
    sketch, img = tf.py_function(preprocess, [path], [tf.float32, tf.float32])
    sketch.set_shape([IMAGE_SIZE, IMAGE_SIZE, 1])
    img.set_shape([IMAGE_SIZE, IMAGE_SIZE, 3])
    return sketch, img


dataset = tf.data.Dataset.from_tensor_slices(image_paths)
dataset = dataset.map(tf_preprocess, num_parallel_calls=AUTOTUNE)
dataset = dataset.shuffle(100).batch(BATCH_SIZE).prefetch(AUTOTUNE)

# %%
# Generator & Discriminator 

#generator
def downsample(filters, size, apply_batchnorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)
    result = tf.keras.Sequential()
    result.add(
        layers.Conv2D(filters, size, strides=2, padding='same',
                      kernel_initializer=initializer, use_bias=False))
    if apply_batchnorm:
        result.add(layers.BatchNormalization())
    result.add(layers.LeakyReLU())
    return result

def upsample(filters, size, apply_dropout=False):
    initializer = tf.random_normal_initializer(0., 0.02)
    result = tf.keras.Sequential()
    result.add(
        layers.Conv2DTranspose(filters, size, strides=2,
                               padding='same',
                               kernel_initializer=initializer,
                               use_bias=False))
    result.add(layers.BatchNormalization())
    if apply_dropout:
        result.add(layers.Dropout(0.5))
    result.add(layers.ReLU())
    return result

def Generator():
    inputs = layers.Input(shape=[IMAGE_SIZE, IMAGE_SIZE, 1])
    down_stack = [
        downsample(64, 4, apply_batchnorm=False),
        downsample(128, 4),
        downsample(256, 4),
        downsample(512, 4),
    ]
    up_stack = [
        upsample(512, 4, apply_dropout=True),
        upsample(256, 4),
        upsample(128, 4),
        upsample(64, 4),
    ]
    initializer = tf.random_normal_initializer(0., 0.02)
    last = layers.Conv2DTranspose(3, 4,
                                  strides=2,
                                  padding='same',
                                  kernel_initializer=initializer,
                                  activation='tanh')  # [-1, 1] normalised pixel values already in sketches

    x = inputs
    skips = []
    for down in down_stack:
        x = down(x)
        skips.append(x)
    skips = reversed(skips[:-1])

    for up, skip in zip(up_stack, skips):
        x = up(x)
        x = layers.Concatenate()([x, skip])

    x = last(x)
    return tf.keras.Model(inputs=inputs, outputs=x)

#discriminator

def Discriminator():
    initializer = tf.random_normal_initializer(0., 0.02)
    inp = layers.Input(shape=[IMAGE_SIZE, IMAGE_SIZE, 1], name='input_image')
    tar = layers.Input(shape=[IMAGE_SIZE, IMAGE_SIZE, 3], name='target_image')
    x = layers.Concatenate()([inp, tar])
    down1 = downsample(64, 4, False)(x)
    down2 = downsample(128, 4)(down1)
    down3 = downsample(256, 4)(down2)
    zero_pad1 = layers.ZeroPadding2D()(down3)
    conv = layers.Conv2D(512, 4, strides=1, kernel_initializer=initializer, use_bias=False)(zero_pad1)
    batchnorm1 = layers.BatchNormalization()(conv)
    leaky_relu = layers.LeakyReLU()(batchnorm1)
    zero_pad2 = layers.ZeroPadding2D()(leaky_relu)
    last = layers.Conv2D(1, 4, strides=1, kernel_initializer=initializer)(zero_pad2)
    return tf.keras.Model(inputs=[inp, tar], outputs=last)

# %%
# Losses computation
loss_obj = tf.keras.losses.BinaryCrossentropy(from_logits=True)

def discriminator_loss(disc_real_output, disc_generated_output):
    real_loss = loss_obj(tf.ones_like(disc_real_output), disc_real_output)
    generated_loss = loss_obj(tf.zeros_like(disc_generated_output), disc_generated_output)
    return real_loss + generated_loss

def generator_loss(disc_generated_output, gen_output, target):
    gan_loss = loss_obj(tf.ones_like(disc_generated_output), disc_generated_output)
    l1_loss = tf.reduce_mean(tf.abs(target - gen_output))
    total_gen_loss = gan_loss + (100 * l1_loss)
    return total_gen_loss

# %%
# Training  function
generator = Generator()
discriminator = Discriminator()

generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)
discriminator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

@tf.function
def train_step(input_image, target):
    with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
        gen_output = generator(input_image, training=True)
        disc_real_output = discriminator([input_image, target], training=True)
        disc_generated_output = discriminator([input_image, gen_output], training=True)

        gen_loss = generator_loss(disc_generated_output, gen_output, target)
        disc_loss = discriminator_loss(disc_real_output, disc_generated_output)

    generator_gradients = gen_tape.gradient(gen_loss, generator.trainable_variables)
    discriminator_gradients = disc_tape.gradient(disc_loss, discriminator.trainable_variables)

    generator_optimizer.apply_gradients(zip(generator_gradients, generator.trainable_variables))
    discriminator_optimizer.apply_gradients(zip(discriminator_gradients, discriminator.trainable_variables))
    return gen_loss, disc_loss

# %%
import os
import tensorflow as tf

checkpoint_dir = './checkpoints' # saving checkpoints we will finally load the lasst model although
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")

checkpoint = tf.train.Checkpoint(generator=generator,
                                 discriminator=discriminator,
                                 generator_optimizer=generator_optimizer,
                                 discriminator_optimizer=discriminator_optimizer)

manager = tf.train.CheckpointManager(checkpoint, checkpoint_dir, max_to_keep=5)

# %%
SAVE_EVERY_N_STEPS = 200 

for epoch in range(EPOCHS): # training loop
    print(f"\nEpoch {epoch + 1}/{EPOCHS}")
    for step, (sketch, real_image) in enumerate(dataset):
        gen_loss, disc_loss = train_step(sketch, real_image)

        if step % 100 == 0:
            print(f"Step {step}: Gen Loss = {gen_loss:.4f}, Disc Loss = {disc_loss:.4f}")

        if step % SAVE_EVERY_N_STEPS == 0 and step > 0:
            save_path = manager.save()
            print(f"✅ Checkpoint saved at step {step} -> {save_path}")
# Out:
# Epoch 1/10
# Step 0: Gen Loss = 55.1909, Disc Loss = 0.6052
# Step 100: Gen Loss = 49.6535, Disc Loss = 1.3756
# Step 200: Gen Loss = 53.4858, Disc Loss = 0.4311
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-1
# Step 300: Gen Loss = 54.5312, Disc Loss = 0.1989
# Step 400: Gen Loss = 47.6381, Disc Loss = 1.1575
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-2
# Step 500: Gen Loss = 41.4510, Disc Loss = 0.6052
# Step 600: Gen Loss = 45.0640, Disc Loss = 1.0489
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-3
# Step 700: Gen Loss = 61.9529, Disc Loss = 1.7347
# Step 800: Gen Loss = 34.8243, Disc Loss = 2.2654
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-4
# Step 900: Gen Loss = 48.7836, Disc Loss = 0.3985
# Step 1000: Gen Loss = 51.9044, Disc Loss = 0.2671
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-5
# Step 1100: Gen Loss = 51.5028, Disc Loss = 0.4197
# Step 1200: Gen Loss = 50.9569, Disc Loss = 0.6846
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-6
# Step 1300: Gen Loss = 48.3555, Disc Loss = 0.3616
# Step 1400: Gen Loss = 47.8566, Disc Loss = 1.4376
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-7
# Step 1500: Gen Loss = 44.4782, Disc Loss = 0.1935
# Step 1600: Gen Loss = 46.4721, Disc Loss = 0.1516
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-8
# Step 1700: Gen Loss = 53.0041, Disc Loss = 0.0523
# Step 1800: Gen Loss = 57.0945, Disc Loss = 0.1641
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-9
#
# Epoch 2/10
# Step 0: Gen Loss = 53.3731, Disc Loss = 0.1470
# Step 100: Gen Loss = 46.8660, Disc Loss = 0.3162
# Step 200: Gen Loss = 49.9470, Disc Loss = 0.2532
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-10
# Step 300: Gen Loss = 46.1406, Disc Loss = 0.2051
# Step 400: Gen Loss = 46.7508, Disc Loss = 1.1747
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-11
# Step 500: Gen Loss = 36.5306, Disc Loss = 0.8362
# Step 600: Gen Loss = 53.9421, Disc Loss = 0.5619
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-12
# Step 700: Gen Loss = 47.5949, Disc Loss = 0.6278
# Step 800: Gen Loss = 55.3564, Disc Loss = 0.3640
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-13
# Step 900: Gen Loss = 42.0877, Disc Loss = 0.5087
# Step 1000: Gen Loss = 57.8814, Disc Loss = 0.1904
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-14
# Step 1100: Gen Loss = 64.0333, Disc Loss = 0.2371
# Step 1200: Gen Loss = 63.2160, Disc Loss = 0.1593
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-15
# Step 1300: Gen Loss = 41.9762, Disc Loss = 0.2156
# Step 1400: Gen Loss = 47.9586, Disc Loss = 0.3252
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-16
# Step 1500: Gen Loss = 39.8519, Disc Loss = 0.1232
# Step 1600: Gen Loss = 39.0218, Disc Loss = 0.1916
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-17
# Step 1700: Gen Loss = 31.9141, Disc Loss = 1.1134
# Step 1800: Gen Loss = 45.1966, Disc Loss = 0.2955
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-18
#
# Epoch 3/10
# Step 0: Gen Loss = 48.1633, Disc Loss = 0.9035
# Step 100: Gen Loss = 34.1766, Disc Loss = 0.7331
# Step 200: Gen Loss = 45.7409, Disc Loss = 0.7040
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-19
# Step 300: Gen Loss = 36.2195, Disc Loss = 0.9637
# Step 400: Gen Loss = 43.4217, Disc Loss = 1.6611
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-20
# Step 500: Gen Loss = 43.8361, Disc Loss = 0.7408
# Step 600: Gen Loss = 38.1832, Disc Loss = 0.2652
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-21
# Step 700: Gen Loss = 46.4686, Disc Loss = 0.4893
# Step 800: Gen Loss = 35.0428, Disc Loss = 0.2679
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-22
# Step 900: Gen Loss = 37.7325, Disc Loss = 0.6596
# Step 1000: Gen Loss = 42.4800, Disc Loss = 0.0883
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-23
# Step 1100: Gen Loss = 38.7427, Disc Loss = 0.0917
# Step 1200: Gen Loss = 41.9750, Disc Loss = 0.2187
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-24
# Step 1300: Gen Loss = 35.5179, Disc Loss = 0.0727
# Step 1400: Gen Loss = 33.9937, Disc Loss = 0.9051
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-25
# Step 1500: Gen Loss = 38.8591, Disc Loss = 0.6166
# Step 1600: Gen Loss = 41.6888, Disc Loss = 0.0963
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-26
# Step 1700: Gen Loss = 47.1547, Disc Loss = 0.0327
# Step 1800: Gen Loss = 36.5551, Disc Loss = 0.4554
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-27
#
# Epoch 4/10
# Step 0: Gen Loss = 40.9624, Disc Loss = 2.0092
# Step 100: Gen Loss = 30.3787, Disc Loss = 0.3234
# Step 200: Gen Loss = 38.9982, Disc Loss = 0.4118
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-28
# Step 300: Gen Loss = 35.4758, Disc Loss = 0.1541
# Step 400: Gen Loss = 37.7168, Disc Loss = 0.3980
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-29
# Step 500: Gen Loss = 44.6612, Disc Loss = 0.0968
# Step 600: Gen Loss = 32.5146, Disc Loss = 0.2500
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-30
# Step 700: Gen Loss = 37.2099, Disc Loss = 2.0084
# Step 800: Gen Loss = 32.2519, Disc Loss = 0.2463
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-31
# Step 900: Gen Loss = 29.6880, Disc Loss = 0.6780
# Step 1000: Gen Loss = 39.4993, Disc Loss = 0.4630
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-32
# Step 1100: Gen Loss = 49.9952, Disc Loss = 0.0228
# Step 1200: Gen Loss = 32.9394, Disc Loss = 0.3397
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-33
# Step 1300: Gen Loss = 34.6334, Disc Loss = 0.1810
# Step 1400: Gen Loss = 42.0407, Disc Loss = 0.0334
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-34
# Step 1500: Gen Loss = 30.4177, Disc Loss = 1.0404
# Step 1600: Gen Loss = 28.1203, Disc Loss = 4.6545
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-35
# Step 1700: Gen Loss = 35.1748, Disc Loss = 0.1192
# Step 1800: Gen Loss = 36.0006, Disc Loss = 0.7177
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-36
#
# Epoch 5/10
# Step 0: Gen Loss = 39.1620, Disc Loss = 0.1924
# Step 100: Gen Loss = 36.7455, Disc Loss = 0.0148
# Step 200: Gen Loss = 40.2633, Disc Loss = 0.5803
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-37
# Step 300: Gen Loss = 37.7608, Disc Loss = 0.1337
# Step 400: Gen Loss = 30.0347, Disc Loss = 0.0644
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-38
# Step 500: Gen Loss = 26.5894, Disc Loss = 0.2993
# Step 600: Gen Loss = 37.0749, Disc Loss = 1.3893
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-39
# Step 700: Gen Loss = 28.9719, Disc Loss = 0.1985
# Step 800: Gen Loss = 29.2393, Disc Loss = 0.2827
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-40
# Step 900: Gen Loss = 26.9947, Disc Loss = 1.5179
# Step 1000: Gen Loss = 37.0260, Disc Loss = 0.0793
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-41
# Step 1100: Gen Loss = 28.9757, Disc Loss = 0.2249
# Step 1200: Gen Loss = 27.3529, Disc Loss = 1.5963
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-42
# Step 1300: Gen Loss = 28.9256, Disc Loss = 0.3414
# Step 1400: Gen Loss = 26.4450, Disc Loss = 0.5751
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-43
# Step 1500: Gen Loss = 39.2780, Disc Loss = 1.9786
# Step 1600: Gen Loss = 36.6205, Disc Loss = 0.0726
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-44
# Step 1700: Gen Loss = 32.4841, Disc Loss = 1.5410
# Step 1800: Gen Loss = 28.8954, Disc Loss = 0.1994
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-45
#
# Epoch 6/10
# Step 0: Gen Loss = 38.5454, Disc Loss = 0.7668
# Step 100: Gen Loss = 33.0274, Disc Loss = 0.2374
# Step 200: Gen Loss = 43.5748, Disc Loss = 0.0563
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-46
# Step 300: Gen Loss = 25.4361, Disc Loss = 1.2690
# Step 400: Gen Loss = 23.3510, Disc Loss = 0.2700
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-47
# Step 500: Gen Loss = 21.7475, Disc Loss = 0.9136
# Step 600: Gen Loss = 32.7905, Disc Loss = 0.0533
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-48
# Step 700: Gen Loss = 22.9495, Disc Loss = 0.7106
# Step 800: Gen Loss = 32.3551, Disc Loss = 0.5872
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-49
# Step 900: Gen Loss = 39.1852, Disc Loss = 0.0509
# Step 1000: Gen Loss = 33.7859, Disc Loss = 0.0602
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-50
# Step 1100: Gen Loss = 34.2860, Disc Loss = 0.2523
# Step 1200: Gen Loss = 29.8096, Disc Loss = 0.0732
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-51
# Step 1300: Gen Loss = 22.0221, Disc Loss = 1.7148
# Step 1400: Gen Loss = 24.5103, Disc Loss = 0.4860
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-52
# Step 1500: Gen Loss = 32.5342, Disc Loss = 0.5493
# Step 1600: Gen Loss = 34.3298, Disc Loss = 0.1247
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-53
# Step 1700: Gen Loss = 24.4833, Disc Loss = 1.1510
# Step 1800: Gen Loss = 28.7472, Disc Loss = 0.8437
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-54
#
# Epoch 7/10
# Step 0: Gen Loss = 31.1305, Disc Loss = 0.4365
# Step 100: Gen Loss = 25.1714, Disc Loss = 0.3428
# Step 200: Gen Loss = 20.5956, Disc Loss = 3.1947
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-55
# Step 300: Gen Loss = 32.8778, Disc Loss = 0.0377
# Step 400: Gen Loss = 27.6310, Disc Loss = 0.3944
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-56
# Step 500: Gen Loss = 24.2002, Disc Loss = 0.0942
# Step 600: Gen Loss = 28.3457, Disc Loss = 0.2942
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-57
# Step 700: Gen Loss = 25.4421, Disc Loss = 0.0905
# Step 800: Gen Loss = 32.4092, Disc Loss = 0.2899
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-58
# Step 900: Gen Loss = 36.2967, Disc Loss = 0.0845
# Step 1000: Gen Loss = 30.6541, Disc Loss = 0.4091
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-59
# Step 1100: Gen Loss = 24.0046, Disc Loss = 0.4555
# Step 1200: Gen Loss = 35.2748, Disc Loss = 0.0194
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-60
# Step 1300: Gen Loss = 28.8717, Disc Loss = 0.1171
# Step 1400: Gen Loss = 24.8788, Disc Loss = 0.5322
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-61
# Step 1500: Gen Loss = 33.3327, Disc Loss = 0.2704
# Step 1600: Gen Loss = 29.4857, Disc Loss = 0.9970
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-62
# Step 1700: Gen Loss = 23.6614, Disc Loss = 1.3032
# Step 1800: Gen Loss = 23.3904, Disc Loss = 2.8317
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-63
#
# Epoch 8/10
# Step 0: Gen Loss = 28.2703, Disc Loss = 0.2711
# Step 100: Gen Loss = 28.2054, Disc Loss = 0.9083
# Step 200: Gen Loss = 39.7486, Disc Loss = 0.0560
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-64
# Step 300: Gen Loss = 27.7912, Disc Loss = 0.1352
# Step 400: Gen Loss = 26.6591, Disc Loss = 0.1635
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-65
# Step 500: Gen Loss = 27.8016, Disc Loss = 0.0898
# Step 600: Gen Loss = 25.2921, Disc Loss = 0.5628
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-66
# Step 700: Gen Loss = 33.9689, Disc Loss = 0.1997
# Step 800: Gen Loss = 22.5226, Disc Loss = 0.9574
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-67
# Step 900: Gen Loss = 24.7773, Disc Loss = 0.3489
# Step 1000: Gen Loss = 37.9577, Disc Loss = 0.0918
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-68
# Step 1100: Gen Loss = 27.2955, Disc Loss = 0.3369
# Step 1200: Gen Loss = 32.5786, Disc Loss = 0.0916
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-69
# Step 1300: Gen Loss = 26.9106, Disc Loss = 0.4367
# Step 1400: Gen Loss = 39.4601, Disc Loss = 0.0550
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-70
# Step 1500: Gen Loss = 29.8772, Disc Loss = 0.1314
# Step 1600: Gen Loss = 28.2769, Disc Loss = 0.7560
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-71
# Step 1700: Gen Loss = 24.3485, Disc Loss = 0.1466
# Step 1800: Gen Loss = 27.0599, Disc Loss = 0.3292
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-72
#
# Epoch 9/10
# Step 0: Gen Loss = 34.5814, Disc Loss = 0.2719
# Step 100: Gen Loss = 26.1746, Disc Loss = 0.2531
# Step 200: Gen Loss = 30.4898, Disc Loss = 0.2110
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-73
# Step 300: Gen Loss = 17.8980, Disc Loss = 1.8246
# Step 400: Gen Loss = 25.1511, Disc Loss = 1.3221
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-74
# Step 500: Gen Loss = 25.2748, Disc Loss = 0.2939
# Step 600: Gen Loss = 22.1757, Disc Loss = 0.1779
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-75
# Step 700: Gen Loss = 21.5535, Disc Loss = 0.7297
# Step 800: Gen Loss = 23.4750, Disc Loss = 1.1656
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-76
# Step 900: Gen Loss = 21.8963, Disc Loss = 0.9166
# Step 1000: Gen Loss = 25.3167, Disc Loss = 0.1779
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-77
# Step 1100: Gen Loss = 18.4727, Disc Loss = 0.8462
# Step 1200: Gen Loss = 35.7156, Disc Loss = 0.3816
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-78
# Step 1300: Gen Loss = 21.4925, Disc Loss = 0.3881
# Step 1400: Gen Loss = 32.0481, Disc Loss = 0.0972
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-79
# Step 1500: Gen Loss = 19.4645, Disc Loss = 0.5705
# Step 1600: Gen Loss = 24.4858, Disc Loss = 0.2124
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-80
# Step 1700: Gen Loss = 28.6424, Disc Loss = 0.8879
# Step 1800: Gen Loss = 26.1218, Disc Loss = 0.4345
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-81
#
# Epoch 10/10
# Step 0: Gen Loss = 22.2730, Disc Loss = 0.3662
# Step 100: Gen Loss = 30.0369, Disc Loss = 0.7814
# Step 200: Gen Loss = 23.6688, Disc Loss = 0.8920
# ✅ Checkpoint saved at step 200 -> ./checkpoints\ckpt-82
# Step 300: Gen Loss = 24.9474, Disc Loss = 0.1500
# Step 400: Gen Loss = 27.0849, Disc Loss = 1.7389
# ✅ Checkpoint saved at step 400 -> ./checkpoints\ckpt-83
# Step 500: Gen Loss = 15.9125, Disc Loss = 0.7932
# Step 600: Gen Loss = 34.3667, Disc Loss = 0.1604
# ✅ Checkpoint saved at step 600 -> ./checkpoints\ckpt-84
# Step 700: Gen Loss = 29.8841, Disc Loss = 0.0272
# Step 800: Gen Loss = 24.2924, Disc Loss = 0.6051
# ✅ Checkpoint saved at step 800 -> ./checkpoints\ckpt-85
# Step 900: Gen Loss = 25.6867, Disc Loss = 0.1717
# Step 1000: Gen Loss = 19.1381, Disc Loss = 0.3066
# ✅ Checkpoint saved at step 1000 -> ./checkpoints\ckpt-86
# Step 1100: Gen Loss = 29.8900, Disc Loss = 0.6824
# Step 1200: Gen Loss = 19.8782, Disc Loss = 0.5495
# ✅ Checkpoint saved at step 1200 -> ./checkpoints\ckpt-87
# Step 1300: Gen Loss = 28.7623, Disc Loss = 0.0975
# Step 1400: Gen Loss = 21.8768, Disc Loss = 0.4487
# ✅ Checkpoint saved at step 1400 -> ./checkpoints\ckpt-88
# Step 1500: Gen Loss = 25.8483, Disc Loss = 0.9045
# Step 1600: Gen Loss = 28.2120, Disc Loss = 0.4033
# ✅ Checkpoint saved at step 1600 -> ./checkpoints\ckpt-89
# Step 1700: Gen Loss = 25.9246, Disc Loss = 0.7043
# Step 1800: Gen Loss = 23.3207, Disc Loss = 0.1588
# ✅ Checkpoint saved at step 1800 -> ./checkpoints\ckpt-90

# %%
#final saving of model
generator.save("generator_sketch2image.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
